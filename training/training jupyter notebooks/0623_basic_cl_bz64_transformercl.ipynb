# %%
function KeepClicking(){
console.log("Clicking");
document.querySelector("colab-connect-button").click()
}
setInterval(KeepClicking,60000)
Open your Chrome DevTools by pressing F12 or ctrl+shift+i on Linux and enter the following JavaScript snippet in your console:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install transformers
# !pip install pytorch_transformers
# Mount google drive
# !pip install -r drive/MyDrive/transformers_cl/requirements.txt

# %% [markdown]
# # root_2

# %% [markdown]
# MSDialog root-2
#
# root_2 see root_2_transformer_cl.ipynb

# %% [markdown]
# # root_5

# %% [markdown]
# MSDialog root-5

# %%
# done 6-1 msdialog root_5
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root5_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_5\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 07:24:48 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 07:24:48 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp2eoq1xc5
# 100% 433/433 [00:00<00:00, 409962.45B/s]
# 06/23/2021 07:24:48 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp2eoq1xc5 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 07:24:48 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# done 6-2 msdialog root_5
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root5_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_5\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 09:22:06 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 09:22:06 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 09:22:06 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 6-3 msdialog root_5
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root5_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_5\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 11:19:03 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 11:19:03 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 11:19:03 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # root_10

# %% [markdown]
# MSDialog root_10

# %%
# done 7-1 msdialog root_10
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root10_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_10\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 07:33:27 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 07:33:28 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpa3qdtgrj
# 100% 433/433 [00:00<00:00, 616683.75B/s]
# 06/23/2021 07:33:28 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpa3qdtgrj to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 07:33:28 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# done 7-2 msdialog root_10
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root10_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_10\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 09:38:08 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 09:38:08 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 09:38:08 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 7-3 msdialog root_10
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root10_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_10\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 11:42:45 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 11:42:45 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 11:42:45 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 7-4 msdialog root_10
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root10_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_10\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %%
# done 7-5 msdialog root_10
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_root10_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_10\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %% [markdown]
# # standard_training

# %% [markdown]
# MSDialog standard_training
#
# standard_training see root_2_transformer_cl.ipynb

# %% [markdown]
# # geom_progression

# %% [markdown]
# MSdialog geom_progression

# %%
# done 2-1 msdialog geom_progression 
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geom_progression_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function geom_progression\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 07:30:37 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 07:30:37 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpskx4xi97
# 100% 433/433 [00:00<00:00, 428737.87B/s]
# 06/23/2021 07:30:37 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpskx4xi97 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 07:30:37 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# done 2-2 msdialog geom_progression 
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geom_progression_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function geom_progression\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 09:36:42 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 09:36:42 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 09:36:42 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 2-3 msdialog geom_progression 
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geom_progression_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function geom_progression\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 14:06:46 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 14:06:47 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmprz04q2qq
# 100% 433/433 [00:00<00:00, 413603.65B/s]
# 06/23/2021 14:06:47 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmprz04q2qq to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 14:06:47 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# done 2-4 msdialog geom_progression 
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geom_progression_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function geom_progression\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %%
# done 2-5 msdialog geom_progression 
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geom_progression_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function geom_progression\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %% [markdown]
# # linear

# %% [markdown]
# MSdialog linear

# %%
# done 3-1 msdialog linear
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 07:35:46 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 07:35:46 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpe00s1xkh
# 100% 433/433 [00:00<00:00, 414264.06B/s]
# 06/23/2021 07:35:46 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpe00s1xkh to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 07:35:46 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# done 3-2 msdialog linear
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 09:43:51 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 09:43:51 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 09:43:51 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 3-3 msdialog linear
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 11:51:39 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 11:51:40 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 11:51:40 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 3-4 msdialog linear
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %%
# done 3-5 msdialog linear
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %% [markdown]
# # step

# %% [markdown]
# MSdialog step

# %%
# done 4-1 msdialog step
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 14:48:56 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 14:48:57 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpkuw9t58z
# 100% 433/433 [00:00<00:00, 617732.53B/s]
# 06/23/2021 14:48:57 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpkuw9t58z to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 14:48:57 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# done 4-2 msdialog step
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 16:56:19 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 16:56:19 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 16:56:19 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 4-3 msdialog step
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 06/23/2021 16:18:39 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/23/2021 16:18:39 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/23/2021 16:18:39 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# done 4-4 msdialog step
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\

# %%
# 4-5 msdialog step
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
