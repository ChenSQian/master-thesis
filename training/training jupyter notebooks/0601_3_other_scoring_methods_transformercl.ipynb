# %%
function KeepClicking(){
console.log("Clicking");
document.querySelector("colab-connect-button").click()
}
setInterval(KeepClicking,60000)
Open your Chrome DevTools by pressing F12 or ctrl+shift+i on Linux and enter the following JavaScript snippet in your console:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install transformers
# !pip install pytorch_transformers
# Mount google drive
# !pip install -r drive/MyDrive/transformers_cl/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 184kB 2.9MB/s
# ...
#      |████████████████████████████████| 901kB 15.1MB/s
# ...
#      |████████████████████████████████| 133kB 39.3MB/s
# ...
#      |████████████████████████████████| 1.2MB 37.6MB/s
# ...
#      |████████████████████████████████| 81kB 8.0MB/s
# ...
#      |████████████████████████████████| 7.6MB 29.2MB/s
# ...
# ERROR: botocore 1.20.84 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#      |████████████████████████████████| 122kB 2.9MB/s
# ...

# %% [markdown]
# MSDialog _utt_avg_words_c_values_3

# %%
# done 1-1 msdialog root_2 _utt_avg_words_c_values_3 batchsize 64 cuda out of memory 4h
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=32   \
    --per_gpu_train_batch_size=32   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_utt_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_utt_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
# Out:
# 05/31/2021 10:37:01 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 05/31/2021 10:37:02 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 05/31/2021 10:37:02 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# 1-2 msdialog root_2 _utt_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_utt_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_utt_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 1-3 msdialog root_2 _utt_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_utt_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_utt_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 1-4 msdialog root_2 _utt_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_utt_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_utt_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 1-5 msdialog root_2 _utt_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_utt_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_utt_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %% [markdown]
# MSDialog _turns_c_values_3

# %%
# done 2-1 msdialog root_2 _turns_c_values_3 64 out of memory
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=32   \
    --per_gpu_train_batch_size=32   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_turn_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_turns_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
# Out:
# 06/01/2021 08:00:10 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/01/2021 08:00:11 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/01/2021 08:00:11 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# 2-2 msdialog root_2 _turns_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_turn_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_turns_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 2-3 msdialog root_2 _turns_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_turn_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_turns_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 2-4 msdialog root_2 _turns_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_turn_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_turns_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 2-5 msdialog root_2 _turns_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_turn_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_turns_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %% [markdown]
# MSDialog _cand_docs_avg_words_c_values_3

# %%
# 3-1 msdialog root_2 _cand_docs_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_doc_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_cand_docs_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
# Out:
# 06/01/2021 08:24:01 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/01/2021 08:24:01 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpekuccl1y
# 100% 433/433 [00:00<00:00, 464840.96B/s]
# 06/01/2021 08:24:01 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpekuccl1y to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/01/2021 08:24:01 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# 3-2 msdialog root_2 _cand_docs_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_doc_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_cand_docs_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 3-3 msdialog root_2 _cand_docs_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_doc_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_cand_docs_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 3-4 msdialog root_2 _cand_docs_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_doc_seed_4 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_cand_docs_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \

# %%
# 3-5 msdialog root_2 _cand_docs_avg_words_c_values_3
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_doc_seed_5 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/MSDialog/_cand_docs_avg_words_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
