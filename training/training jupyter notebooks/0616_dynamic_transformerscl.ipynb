# %%
function KeepClicking(){
console.log("Clicking");
document.querySelector("colab-connect-button").click()
}
setInterval(KeepClicking,60000)
Open your Chrome DevTools by pressing F12 or ctrl+shift+i on Linux and enter the following JavaScript snippet in your console:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install transformers and requirements
# !pip install pytorch_transformers
# !pip install -r drive/MyDrive/transformers_cl/requirements.txt

# %% [markdown]
# # dynamic MSDialog 0-epoch trained starting cl file

# %%
# changed the starting cl file generated by the original untrained model
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_root_2_seed_1 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_0/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\

# %%
# seed 2, epoch 0 3h
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_0_root_2_seed_2 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_0/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/16/2021 07:19:47 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/16/2021 07:19:47 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpd1emcw0s
# 100% 433/433 [00:00<00:00, 659453.03B/s]
# 06/16/2021 07:19:47 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpd1emcw0s to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/16/2021 07:19:47 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 3, epoch 0
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_0_root_2_seed_3 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_0/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/16/2021 10:19:38 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/16/2021 10:19:38 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/16/2021 10:19:38 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_root_2_seed_4 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_0/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 09:42:11 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 09:42:11 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpz8ewj_kc
# 100% 433/433 [00:00<00:00, 391323.77B/s]
# 06/19/2021 09:42:12 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpz8ewj_kc to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 09:42:12 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_root_2_seed_5 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_0/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 12:31:47 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 12:31:47 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 12:31:47 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # dynamic MSDialog 1-epoch trained starting cl file

# %%
# would the starting cl file affect the result??
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_1_root_2_seed_1 \
    --curriculum_file drive/MyDrive/ms_v2_bert_1/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 08:21:49 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 08:21:49 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpy04s4msd
# 100% 433/433 [00:00<00:00, 401355.50B/s]
# 06/17/2021 08:21:49 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpy04s4msd to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 08:21:49 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_1_root_2_seed_2 \
    --curriculum_file drive/MyDrive/ms_v2_bert_1/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 11:07:06 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 11:07:06 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 11:07:06 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3 epoch 3 
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_1_root_2_seed_3 \
    --curriculum_file drive/MyDrive/ms_v2_bert_1/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 14:11:24 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 14:11:24 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp0prlcqfq
# 100% 433/433 [00:00<00:00, 457464.39B/s]
# 06/17/2021 14:11:25 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp0prlcqfq to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 14:11:25 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_1_root_2_seed_4 \
    --curriculum_file drive/MyDrive/ms_v2_bert_1/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/21/2021 07:40:40 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/21/2021 07:40:41 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmprhp81y6u
# 100% 433/433 [00:00<00:00, 372158.53B/s]
# 06/21/2021 07:40:41 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmprhp81y6u to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/21/2021 07:40:41 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_1_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_1/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/21/2021 11:17:18 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/21/2021 11:17:18 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpux1f_618
# 100% 433/433 [00:00<00:00, 509148.76B/s]
# 06/21/2021 11:17:18 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpux1f_618 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/21/2021 11:17:18 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # dynamic MSDialog 2-epoch trained starting cl file

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_2_root_2_seed_1 \
    --curriculum_file  drive/MyDrive/ms_v2_bert_2/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 08:19:54 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 08:19:54 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpc_7nf_t5
# 100% 433/433 [00:00<00:00, 431180.82B/s]
# 06/17/2021 08:19:54 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpc_7nf_t5 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 08:19:54 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_2_root_2_seed_2 \
    --curriculum_file  drive/MyDrive/ms_v2_bert_2/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 12:32:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 12:32:25 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp0s2wl572
# 100% 433/433 [00:00<00:00, 411821.69B/s]
# 06/17/2021 12:32:26 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp0s2wl572 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 12:32:26 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_2_root_2_seed_3 \
    --curriculum_file  drive/MyDrive/ms_v2_bert_2/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 18:44:18 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 18:44:18 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp_suhupy_
# 100% 433/433 [00:00<00:00, 585283.16B/s]
# 06/17/2021 18:44:18 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp_suhupy_ to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 18:44:18 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_2_root_2_seed_4 \
    --curriculum_file  drive/MyDrive/ms_v2_bert_2/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 09:46:54 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 09:46:55 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 09:46:55 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_2_root_2_seed_5 \
    --curriculum_file  drive/MyDrive/ms_v2_bert_2/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 12:48:54 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 12:48:54 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 12:48:54 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # dynamic MSDialog 3-epoch trained starting cl file

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_3_root_2_seed_1 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/16/2021 06:46:01 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/16/2021 06:46:01 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/16/2021 06:46:01 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_3_root_2_seed_2 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/16/2021 09:56:34 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/16/2021 09:56:34 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/16/2021 09:56:34 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_3_root_2_seed_3 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 08:04:54 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 08:04:55 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmphfrm8yl8
# 100% 433/433 [00:00<00:00, 419333.56B/s]
# 06/17/2021 08:04:55 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmphfrm8yl8 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 08:04:55 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_3_root_2_seed_4 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 09:38:28 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 09:38:28 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmppoyfshve
# 100% 433/433 [00:00<00:00, 608216.22B/s]
# 06/19/2021 09:38:28 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmppoyfshve to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 09:38:28 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_3_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 12:26:48 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 12:26:48 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 12:26:48 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # dynamic MSDialog 4-epoch trained starting cl file

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_4_root_2_seed_1 \
    --curriculum_file drive/MyDrive/ms_v2_bert_4/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 08:10:13 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 08:10:13 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp6nl9n76w
# 100% 433/433 [00:00<00:00, 656829.52B/s]
# 06/17/2021 08:10:13 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp6nl9n76w to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 08:10:13 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_4_root_2_seed_2 \
    --curriculum_file drive/MyDrive/ms_v2_bert_4/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 10:56:52 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 10:56:52 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 10:56:52 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_4_root_2_seed_3 \
    --curriculum_file drive/MyDrive/ms_v2_bert_4/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/17/2021 13:45:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/17/2021 13:45:25 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpc4t0_1j4
# 100% 433/433 [00:00<00:00, 655170.86B/s]
# 06/17/2021 13:45:25 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpc4t0_1j4 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/17/2021 13:45:25 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_4_root_2_seed_4 \
    --curriculum_file drive/MyDrive/ms_v2_bert_4/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 09:34:35 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 09:34:35 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpuljvadm7
# 100% 433/433 [00:00<00:00, 413980.77B/s]
# 06/19/2021 09:34:36 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpuljvadm7 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 09:34:36 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_4_root_2_seed_5 \
    --curriculum_file drive/MyDrive/ms_v2_bert_4/preds_dif_c_values_3 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/19/2021 12:30:51 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/19/2021 12:30:52 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/19/2021 12:30:52 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# ------------------------------------------------------------------------------------------trial---------------------------------------------------------------------------------------------

# %% [markdown]
# # dynamic MSDialog root-2

# %%
# done 1-1 msdialog preds_dif root_2 dynamic seed 1 3h3m
# all the preds_dif files are the same ???
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=32   \
    --per_gpu_train_batch_size=32   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_root_2_seed_1 \
    --curriculum_file  drive/MyDrive/MSDialog/preds_dif_run_seed_42 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
   --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/14/2021 07:36:16 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/14/2021 07:36:16 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpbw6q3kcy
# 100% 433/433 [00:00<00:00, 658496.60B/s]
# 06/14/2021 07:36:16 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpbw6q3kcy to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/14/2021 07:36:16 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # cl unchanged

# %%
# trying to debug
# !python drive/MyDrive/transformers_cl/new_run_glue_1.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=32   \
    --per_gpu_train_batch_size=32   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_root_2_seed_1_clunchange \
    --curriculum_file  drive/MyDrive/MSDialog/preds_dif_run_seed_42 \
    --pacing_function root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 06/14/2021 21:44:32 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/14/2021 21:44:32 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpj8t6eaz_
# 100% 433/433 [00:00<00:00, 570393.73B/s]
# 06/14/2021 21:44:32 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpj8t6eaz_ to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/14/2021 21:44:32 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # using untrained preds_dif file

# %%
# use preds_dif from untrained bert 
# !python drive/MyDrive/transformers_cl/run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=32   \
    --per_gpu_train_batch_size=32   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_untrained_seed_1 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert/preds_dif_c_values_3 \
    --pacing_function root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --invert_cl_values\
# Out:
# 06/14/2021 20:23:49 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/14/2021 20:23:49 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp24_2ixjc
# 100% 433/433 [00:00<00:00, 397316.48B/s]
# 06/14/2021 20:23:50 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp24_2ixjc to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/14/2021 20:23:50 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # using 3-epoch trained preds_dif file

# %%
# done 1-1 msdialog preds_dif root_2 seed 1 2h10m as 对照组
# !python drive/MyDrive/transformers_cl/run_glue.py \
#     --model_type bert \
#     --model_name_or_path bert-base-uncased \
#     --task_name  ms_v2 \
#     --do_train \
#     --evaluate_during_training \
#     --do_lower_case \
#     --data_dir drive/MyDrive/MSDialog \
#     --max_seq_length 128 \
#     --per_gpu_eval_batch_size=32   \
#     --per_gpu_train_batch_size=32   \
#     --learning_rate 2e-5 \
#     --num_train_epochs 2 \
#     --seed 1\
#     --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_root_2_seed_1 \
#     --curriculum_file  drive/MyDrive/MSDialog/preds_dif_run_seed_42 \
#     --pacing_function root_2\
#     --use_additive_cl \
#     --eval_all_checkpoints \
#     --logging_steps 100\
#     --save_aps \
#     --invert_cl_values\
# Out:
# 06/14/2021 08:57:39 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 06/14/2021 08:57:39 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpxge2qk43
# 100% 433/433 [00:00<00:00, 603366.66B/s]
# 06/14/2021 08:57:39 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpxge2qk43 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 06/14/2021 08:57:39 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...
