# %%
function KeepClicking(){
console.log("Clicking");
document.querySelector("colab-connect-button").click()
}
setInterval(KeepClicking,60000)
Open your Chrome DevTools by pressing F12 or ctrl+shift+i on Linux and enter the following JavaScript snippet in your console:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install transformers
# !pip install pytorch_transformers
# Mount google drive
# !pip install -r drive/MyDrive/transformers_cl/requirements.txt

# %% [markdown]
# # geo-step

# %%
# seed 1
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_step_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/08/2021 19:37:21 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/08/2021 19:37:21 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/08/2021 19:37:21 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_step_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/08/2021 21:46:59 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/08/2021 21:46:59 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/08/2021 21:46:59 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_step_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression step\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 10:52:20 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 10:52:21 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpj2urztny
# 100% 433/433 [00:00<00:00, 496075.84B/s]
# 07/09/2021 10:52:21 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpj2urztny to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 10:52:21 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # geo-linear

# %%
# seed 1
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_linear_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/08/2021 23:56:29 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/08/2021 23:56:29 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/08/2021 23:56:29 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_linear_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 13:07:55 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 13:07:55 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 13:07:55 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_linear_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 06:54:15 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 06:54:16 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp9vx1wgy4
# 100% 433/433 [00:00<00:00, 394554.34B/s]
# 07/10/2021 06:54:16 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp9vx1wgy4 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 06:54:16 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # geo-root_2

# %%
# seed 1
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_root2_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 05:31:47 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 05:31:48 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp159293we
# 100% 433/433 [00:00<00:00, 453919.93B/s]
# 07/09/2021 05:31:48 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp159293we to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 05:31:48 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_root2_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 09:18:20 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 09:18:20 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 09:18:20 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_geo_root2_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions geom_progression root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 11:26:47 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 11:26:48 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 11:26:48 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # step-linear

# %%
# seed 1
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_linear_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions step linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 07:36:03 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 07:36:03 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 07:36:03 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_linear_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions step linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 20:12:06 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 20:12:06 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpe_gf9esa
# 100% 433/433 [00:00<00:00, 539712.82B/s]
# 07/10/2021 20:12:06 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpe_gf9esa to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 20:12:06 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_linear_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions step linear\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 22:21:15 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 22:21:15 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 22:21:15 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # step-root_2

# %%
# seed 1
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_root2_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions step root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 07:39:07 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 07:39:07 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpeeqc_tbs
# 100% 433/433 [00:00<00:00, 400647.17B/s]
# 07/09/2021 07:39:07 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpeeqc_tbs to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 07:39:07 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_root2_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions step root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 09:49:40 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 09:49:40 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 09:49:40 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_step_root2_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions step root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 07:22:03 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 07:22:03 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmph3pxzhdo
# 100% 433/433 [00:00<00:00, 538273.16B/s]
# 07/10/2021 07:22:03 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmph3pxzhdo to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 07:22:03 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # linear-root_2

# %%
# seed 1
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_root2_seed_1 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions linear root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/09/2021 12:10:18 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 12:10:18 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 12:10:18 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_root2_seed_2 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions linear root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 11:34:07 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 11:34:07 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 11:34:07 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_linear_root2_seed_3 \
    --logging_steps 100 \
    --curriculum_file  drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions linear root_2\
    --use_additive_cl \
    --eval_all_checkpoints \
    --invert_cl_values\
# Out:
# 07/10/2021 09:28:00 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 09:28:00 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 09:28:00 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...
