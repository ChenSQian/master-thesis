# %%
function KeepClicking(){
console.log("Clicking");
document.querySelector("colab-connect-button").click()
}
setInterval(KeepClicking,60000)
Open your Chrome DevTools by pressing F12 or ctrl+shift+i on Linux and enter the following JavaScript snippet in your console:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install transformers and requirements
# !pip install pytorch_transformers
# !pip install -r drive/MyDrive/transformers_cl/requirements.txt

# %% [markdown]
# # dynamic MSDialog 3-epoch trained starting cl file 400

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_34_root_2_seed_1 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/08/2021 19:54:54 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/08/2021 19:54:54 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/08/2021 19:54:54 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2, epoch 3 2h30m
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_34_root_2_seed_2 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 05:30:12 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 05:30:12 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpkngh10xn
# 100% 433/433 [00:00<00:00, 371018.11B/s]
# 07/09/2021 05:30:13 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpkngh10xn to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 05:30:13 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_34_root_2_seed_3 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 08:08:35 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 08:08:35 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 08:08:35 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 4
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_34_root_2_seed_4 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 10:54:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 10:54:25 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpdaa3tbxc
# 100% 433/433 [00:00<00:00, 410982.94B/s]
# 07/09/2021 10:54:25 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpdaa3tbxc to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 10:54:25 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 5
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_34_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 13:23:09 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 13:23:09 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 13:23:09 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %% [markdown]
# # dynamic MSDialog 3-epoch trained starting cl file 800

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_38_root_2_seed_1 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/10/2021 09:31:29 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 09:31:30 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp0rcahk2e
# 100% 433/433 [00:00<00:00, 364246.62B/s]
# 07/10/2021 09:31:30 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp0rcahk2e to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 09:31:30 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_38_root_2_seed_2 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 07:41:47 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 07:41:47 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp2jp6xw8v
# 100% 433/433 [00:00<00:00, 590996.95B/s]
# 07/09/2021 07:41:47 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp2jp6xw8v to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 07:41:47 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_38_root_2_seed_3 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 11:27:26 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 11:27:26 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpc25dwlxi
# 100% 433/433 [00:00<00:00, 399501.46B/s]
# 07/09/2021 11:27:27 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpc25dwlxi to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 11:27:27 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_38_root_2_seed_4 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/09/2021 13:39:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/09/2021 13:39:25 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/09/2021 13:39:25 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic_38_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/ms_v2_bert_3/preds_dif_c_values_3 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/10/2021 06:48:55 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 06:48:55 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpaeoqk06n
# 100% 433/433 [00:00<00:00, 402690.38B/s]
# 07/10/2021 06:48:55 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpaeoqk06n to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 06:48:55 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # 0527 scoring file (batchsize=8, epoch=3, 200)

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic8_root_2_seed_1 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42\
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/10/2021 07:17:55 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 07:17:55 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp7dp7t20w
# 100% 433/433 [00:00<00:00, 438467.80B/s]
# 07/10/2021 07:17:55 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp7dp7t20w to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 07:17:55 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic8_root_2_seed_2 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/10/2021 10:31:41 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 10:31:42 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 10:31:42 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic8_root_2_seed_3 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/10/2021 13:17:15 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 13:17:15 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 13:17:15 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic8_root_2_seed_4 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/10/2021 20:09:48 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/10/2021 20:09:48 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp6eoyflw9
# 100% 433/433 [00:00<00:00, 363372.08B/s]
# 07/10/2021 20:09:48 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp6eoyflw9 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/10/2021 20:09:48 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 3 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic8_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 200\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 06:17:10 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 06:17:10 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpb8v8nq41
# 100% 433/433 [00:00<00:00, 600970.76B/s]
# 07/11/2021 06:17:10 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpb8v8nq41 to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 06:17:10 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # 0527 scoring file (batchsize=8, epoch=2, 400)

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic48_root_2_seed_1 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42\
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 19:26:10 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 19:26:10 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 19:26:10 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic84_root_2_seed_2 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 17:51:16 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 17:51:16 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp5sqai5tt
# 100% 433/433 [00:00<00:00, 404754.54B/s]
# 07/11/2021 17:51:16 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp5sqai5tt to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 17:51:16 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic84_root_2_seed_3 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 22:22:25 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 22:22:25 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp0zar1h7e
# 100% 433/433 [00:00<00:00, 324251.68B/s]
# 07/11/2021 22:22:25 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp0zar1h7e to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 22:22:25 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic84_root_2_seed_4 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 23:53:43 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 23:53:43 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 23:53:43 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic84_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 400\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/12/2021 06:18:22 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/12/2021 06:18:22 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpgjx__m4s
# 100% 433/433 [00:00<00:00, 627985.35B/s]
# 07/12/2021 06:18:22 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpgjx__m4s to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/12/2021 06:18:22 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %% [markdown]
# # 0527 scoring file (batchsize=8, epoch=2, 800)

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 1\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic88_root_2_seed_1 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42\
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 21:10:28 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 21:10:28 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpw_1sb60t
# 100% 433/433 [00:00<00:00, 446224.48B/s]
# 07/11/2021 21:10:29 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpw_1sb60t to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 21:10:29 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# seed 2, epoch 3
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 2\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic88_root_2_seed_2 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/11/2021 22:35:20 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/11/2021 22:35:21 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/11/2021 22:35:21 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...

# %%
# seed 3 epoch 3      
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 3\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic88_root_2_seed_3 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/12/2021 13:00:35 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/12/2021 13:00:36 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp5o681r8a
# 100% 433/433 [00:00<00:00, 373459.52B/s]
# 07/12/2021 13:00:36 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmp5o681r8a to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/12/2021 13:00:36 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 4\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic88_root_2_seed_4 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/12/2021 06:19:20 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/12/2021 06:19:21 - INFO - pytorch_transformers.file_utils -   https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmpmgfv96tq
# 100% 433/433 [00:00<00:00, 313829.90B/s]
# 07/12/2021 06:19:21 - INFO - pytorch_transformers.file_utils -   copying /tmp/tmpmgfv96tq to cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/12/2021 06:19:21 - INFO - pytorch_transformers.file_utils -   creating metadata file for /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# ...

# %%
# !python drive/MyDrive/transformers_cl/new_run_glue.py \
    --model_type bert \
    --model_name_or_path bert-base-uncased \
    --task_name  ms_v2 \
    --do_train \
    --evaluate_during_training \
    --do_lower_case \
    --data_dir drive/MyDrive/MSDialog \
    --max_seq_length 128 \
    --per_gpu_eval_batch_size=64   \
    --per_gpu_train_batch_size=64   \
    --learning_rate 2e-5 \
    --num_train_epochs 2 \
    --seed 5\
    --output_dir drive/MyDrive/transformers_cl/ms_v2_preds_dif_dynamic88_root_2_seed_5 \
    --curriculum_file drive/MyDrive/transformers_cl/preds_dif_run_seed_42 \
    --pacing_functions root_2\
    --scoring_method preds_dif\
    --use_additive_cl \
    --eval_all_checkpoints \
    --logging_steps 100\
    --rescoring_steps 800\
    --save_aps \
    --invert_cl_values\
# Out:
# 07/12/2021 07:50:34 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 07/12/2021 07:50:34 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/pytorch_transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 07/12/2021 07:50:34 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": "ms_v2",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
# ...
